# %%
# !pip install swan
# Out:
# ...
#      ---------------------------------------- 0.0/69.9 kB ? eta -:--:--
#      ---------------------------------------- 69.9/69.9 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for swan: filename=swan-0.7.3-py3-none-any.whl size=29795 sha256=3c4fe0440ce62076dc06a0c0aabe78ef380bf065bcd03acbb288e37ca226434e
#   Stored in directory: c:\users\vchem\appdata\local\pip\cache\wheels\8a\8c\07\fc1a6e627ecb9f634a3695cc37d428e24f7cfef3b3941f9f5a
# Successfully built swan
# ...

# %%
from swan import pycwt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nt = 512
wt = pycwt.cwt_f(np.cos(2*np.pi*0.1*np.arange(nt)), np.arange(0.01, 0.5))

# %%
plt.plot(abs(wt).T)

# %%
help(swan)
# Out:
# Help on package swan:
#
# NAME
#     swan
#
# PACKAGE CONTENTS
#     gui (package)
#     pycwt
#     pydwt
#     rhythm_track
#     utils
#
# FILE
#     c:\users\vchem\anaconda3\lib\site-packages\swan\__init__.py
